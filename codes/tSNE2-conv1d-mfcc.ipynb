# %%
import keras
import os
import librosa


import numpy as np
import pandas as pd

from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler


from keras.models import Sequential
from keras.utils import np_utils
from keras.utils import to_categorical
from keras.layers import Dense, Dropout, GaussianNoise, Conv1D
from keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\lenovo_pc\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
feature_dim_1 = 2

# %%
def get_labels(path):
    labels = os.listdir(path)
    label_indices = np.arange(0, len(labels))    
    return labels, label_indices, to_categorical(label_indices)

# %%
def save_data_to_array(path, max_pad_len):
    labels, _, _ = get_labels(path)

    for label in labels:
        # Init mfcc vectors
        melspectrogram_vectors = []

        wavfiles = [path + '/' + label + '/' + wavfile for wavfile in os.listdir(path + '/' + label)]
        #wavfiles = librosa.util.find_files(db)
        #print(wavfiles)
        x=0
        for wavfile in wavfiles:
            name=label+'_'+str(x)
            melspectrogram = wav2melspectrogram(wavfile, name, max_pad_len=max_pad_len)            
            melspectrogram_vectors.append(melspectrogram)            
            x=x+1
        
        #computing PCA and saving
        
        np.save(label + '.npy', melspectrogram_vectors)
        #y=np.load(label + '.npy')
        #y = sklearn.preprocessing.scale(y)
        #y.mean()
        #model = sklearn.decomposition.PCA(n_components=2, whiten=True)
        #model.fit(y)
        #y = model.transform(y)
        #pd.DataFrame(y).to_csv(VALUE_PATH+'/'+label+'.csv')
        
        
sample_x=[]

def wav2melspectrogram(file_path, name, max_pad_len):
    wave, sr = librosa.load(file_path)
    x = librosa.feature.mfcc(wave, sr=sr)
    pad_width = max_pad_len - x.shape[1]
    x = np.pad(x, pad_width=((0, 0), (0, pad_width)), mode='constant')
    #here the dimensions are getting reduced 
    #through PCA decompostion
    x = reduce_dimension(x)    
    return x.T

# %%
DATA_PATH = r'C:\Users\lenovo_pc\Desktop\CNN_SR\Dataset-merged'

# %% [markdown]
# # t-Distributed Stochastic Neighbour Embedding (t-SNE)
# Like PCA, t-SNE is another dimensionality reduction technique, developed in part by the godfather of machine learning himself, Geoffrey Hinton. Quoting Wikipedia : It is a nonlinear dimensionality reduction technique well-suited for embedding high-dimensional data for visualization in a low-dimensional space of two or three dimensions. Specifically, it models each high-dimensional object by a two- or three-dimensional point in such a way that similar objects are modeled by nearby points and dissimilar objects are modeled by distant points with high probability.

# %% [markdown]
# labels, indices, _ = get_labels(DATA_PATH)
#
#  Getting first arrays
# T = np.load(labels[0] + '.npy')
#  Getting first element of first array
# X = T[127]
# print(X.shape)
#
#  Running t-SNE generating 3 dimensional data points
# print("Calculating TSNE")
# tsne = TSNE(n_components=3, perplexity=40, verbose=2, n_iter=500,early_exaggeration=1)
# tsne0 = tsne.fit_transform(X.T)
# tsne0 = StandardScaler().fit_transform(tsne0)
#
# print(tsne0.T.shape)

# %%
def reduce_dimension(X):
    tsne = TSNE(n_components=feature_dim_1, perplexity=10, verbose=2, n_iter=500,early_exaggeration=1)
    tsne0 = tsne.fit_transform(X.T)
    tsne0 = StandardScaler().fit_transform(tsne0)
    
    return tsne0.T

# %%
from sklearn.model_selection import train_test_split


def get_train_test(split_ratio=0.8, random_state=42):
    # Get available labels
    labels, indices, _ = get_labels(DATA_PATH)

    # Getting first arrays
    X = np.load(labels[0] + '.npy')
    # print(X.shape[0]) returns: 129
    y = np.zeros(X.shape[0])

    # Append all of the dataset into one single array, same goes for y
    for i, label in enumerate(labels[1:]):
        x = np.load(label + '.npy')
        X = np.vstack((X, x))
        #print(X.shape[0]) returns: 129+152=281
        #print(i) returns: 0: So all y values are 1 for Seven and 0 for Tin
        y = np.append(y, np.full(x.shape[0], fill_value= (i + 1)))

    assert X.shape[0] == len(y)

    return train_test_split(X, y, test_size= (1 - split_ratio), random_state=random_state, shuffle=True)

# %%
# Second dimension of the feature is dim2
feature_dim_2 = 28

# Save data to array file first
save_data_to_array(DATA_PATH,feature_dim_2)

# # Loading train set and test set
X_train, X_test, y_train, y_test = get_train_test()

# # Feature dimension
channel = 1
epochs = 50
batch_size = 100
verbose = 1
num_classes = 2


y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)
# Out:
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.040s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.004s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 26.602926
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.8308491, gradient norm = 0.0034308 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: error = 0.6201930, gradient norm = 0.0014943 (50 iterations in 0.024s)
# [t-SNE] Iteration 150: error = 0.5399653, gradient norm = 0.0005751 (50 iterations in 0.024s)
# [t-SNE] Iteration 200: error = 0.7222000, gradient norm = 0.0006480 (50 iterations in 0.032s)
# [t-SNE] Iteration 250: error = 0.6504864, gradient norm = 0.0004844 (50 iterations in 0.032s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.650486
# [t-SNE] Iteration 300: error = 0.5932390, gradient norm = 0.0004804 (50 iterations in 0.036s)
# [t-SNE] Iteration 350: error = 0.4690259, gradient norm = 0.0016645 (50 iterations in 0.028s)
# [t-SNE] Iteration 400: error = 0.4259735, gradient norm = 0.0001360 (50 iterations in 0.028s)
# [t-SNE] Iteration 450: error = 0.4240949, gradient norm = 0.0000525 (50 iterations in 0.024s)
# [t-SNE] Iteration 500: error = 0.4235556, gradient norm = 0.0000303 (50 iterations in 0.024s)
# [t-SNE] Error after 500 iterations: 0.423556
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 10.566586
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.5796172, gradient norm = 0.0030694 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.4500946, gradient norm = 0.0002681 (50 iterations in 0.024s)
# [t-SNE] Iteration 150: error = 0.4481888, gradient norm = 0.0004080 (50 iterations in 0.024s)
# [t-SNE] Iteration 200: error = 0.7389327, gradient norm = 0.0049428 (50 iterations in 0.028s)
# [t-SNE] Iteration 250: error = 0.4590132, gradient norm = 0.0004459 (50 iterations in 0.028s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.459013
# [t-SNE] Iteration 300: error = 0.4521530, gradient norm = 0.0001331 (50 iterations in 0.028s)
# [t-SNE] Iteration 350: error = 0.4510513, gradient norm = 0.0001117 (50 iterations in 0.028s)
# [t-SNE] Iteration 400: error = 0.4489396, gradient norm = 0.0001807 (50 iterations in 0.032s)
# [t-SNE] Iteration 450: error = 0.4483039, gradient norm = 0.0002162 (50 iterations in 0.020s)
# [t-SNE] Iteration 500: error = 0.4460614, gradient norm = 0.0003887 (50 iterations in 0.024s)
# [t-SNE] Error after 500 iterations: 0.446061
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.040s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 7.479480
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 1.0371341, gradient norm = 0.0024122 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.8206086, gradient norm = 0.0018559 (50 iterations in 0.032s)
# [t-SNE] Iteration 150: error = 1.1573976, gradient norm = 0.0015945 (50 iterations in 0.028s)
# [t-SNE] Iteration 200: error = 1.0087223, gradient norm = 0.0006108 (50 iterations in 0.028s)
# [t-SNE] Iteration 250: error = 0.8855982, gradient norm = 0.0005170 (50 iterations in 0.024s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.885598
# [t-SNE] Iteration 300: error = 0.8238704, gradient norm = 0.0004793 (50 iterations in 0.032s)
# [t-SNE] Iteration 350: error = 0.7485751, gradient norm = 0.0002341 (50 iterations in 0.020s)
# [t-SNE] Iteration 400: error = 0.7107058, gradient norm = 0.0002714 (50 iterations in 0.028s)
# [t-SNE] Iteration 450: error = 0.5187222, gradient norm = 0.0022508 (50 iterations in 0.020s)
# [t-SNE] Iteration 500: error = 0.4413364, gradient norm = 0.0002647 (50 iterations in 0.024s)
# [t-SNE] Error after 500 iterations: 0.441336
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 29.910089
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.5726623, gradient norm = 0.0066683 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.4522406, gradient norm = 0.0002109 (50 iterations in 0.024s)
# [t-SNE] Iteration 150: error = 0.4515349, gradient norm = 0.0000962 (50 iterations in 0.032s)
# [t-SNE] Iteration 200: error = 0.4509591, gradient norm = 0.0001304 (50 iterations in 0.028s)
# [t-SNE] Iteration 250: error = 0.4507029, gradient norm = 0.0002398 (50 iterations in 0.028s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.450703
# [t-SNE] Iteration 300: error = 0.4500209, gradient norm = 0.0007810 (50 iterations in 0.028s)
# [t-SNE] Iteration 350: error = 0.4478164, gradient norm = 0.0018172 (50 iterations in 0.028s)
# [t-SNE] Iteration 400: error = 0.4394854, gradient norm = 0.0165227 (50 iterations in 0.024s)
# [t-SNE] Iteration 450: error = 0.6488683, gradient norm = 0.0010513 (50 iterations in 0.032s)
# [t-SNE] Iteration 500: error = 0.5362991, gradient norm = 0.0012429 (50 iterations in 0.024s)
# [t-SNE] Error after 500 iterations: 0.536299
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.036s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 10.498957
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.9723731, gradient norm = 0.0031231 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.5187528, gradient norm = 0.0005690 (50 iterations in 0.028s)
# [t-SNE] Iteration 150: error = 0.4479050, gradient norm = 0.0004131 (50 iterations in 0.032s)
# [t-SNE] Iteration 200: error = 0.4276372, gradient norm = 0.0000748 (50 iterations in 0.024s)
# [t-SNE] Iteration 250: error = 0.4261576, gradient norm = 0.0000311 (50 iterations in 0.036s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.426158
# [t-SNE] Iteration 300: error = 0.4261978, gradient norm = 0.0000258 (50 iterations in 0.028s)
# [t-SNE] Iteration 350: error = 0.4260537, gradient norm = 0.0000207 (50 iterations in 0.024s)
# [t-SNE] Iteration 400: error = 0.4256464, gradient norm = 0.0000209 (50 iterations in 0.024s)
# [t-SNE] Iteration 450: error = 0.4255545, gradient norm = 0.0000177 (50 iterations in 0.020s)
# [t-SNE] Iteration 500: error = 0.4255486, gradient norm = 0.0000211 (50 iterations in 0.020s)
# [t-SNE] Error after 500 iterations: 0.425549
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.004s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 29.925266
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 1.0310905, gradient norm = 0.0388521 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.4857283, gradient norm = 0.0031750 (50 iterations in 0.020s)
# [t-SNE] Iteration 150: error = 0.6741092, gradient norm = 0.0008334 (50 iterations in 0.024s)
# [t-SNE] Iteration 200: error = 0.6077058, gradient norm = 0.0001724 (50 iterations in 0.024s)
# [t-SNE] Iteration 250: error = 0.6006970, gradient norm = 0.0001229 (50 iterations in 0.024s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.600697
# [t-SNE] Iteration 300: error = 0.5935948, gradient norm = 0.0002519 (50 iterations in 0.032s)
# [t-SNE] Iteration 350: error = 0.5656347, gradient norm = 0.0004878 (50 iterations in 0.028s)
# [t-SNE] Iteration 400: error = 0.4868133, gradient norm = 0.0016272 (50 iterations in 0.028s)
# [t-SNE] Iteration 450: error = 0.4657333, gradient norm = 0.0001562 (50 iterations in 0.028s)
# [t-SNE] Iteration 500: error = 0.4544199, gradient norm = 0.0001519 (50 iterations in 0.032s)
# [t-SNE] Error after 500 iterations: 0.454420
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 10.575562
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.4659085, gradient norm = 0.0008524 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.4482920, gradient norm = 0.0010514 (50 iterations in 0.028s)
# [t-SNE] Iteration 150: error = 0.4489520, gradient norm = 0.0032465 (50 iterations in 0.032s)
# [t-SNE] Iteration 200: error = 0.6041145, gradient norm = 0.0018596 (50 iterations in 0.032s)
# [t-SNE] Iteration 250: error = 0.4703936, gradient norm = 0.0002611 (50 iterations in 0.028s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.470394
# [t-SNE] Iteration 300: error = 0.4607343, gradient norm = 0.0001662 (50 iterations in 0.028s)
# [t-SNE] Iteration 350: error = 0.4527986, gradient norm = 0.0001219 (50 iterations in 0.024s)
# [t-SNE] Iteration 400: error = 0.4509023, gradient norm = 0.0000546 (50 iterations in 0.024s)
# [t-SNE] Iteration 450: error = 0.4512977, gradient norm = 0.0000377 (50 iterations in 0.024s)
# [t-SNE] Iteration 500: error = 0.4510134, gradient norm = 0.0000362 (50 iterations in 0.020s)
# [t-SNE] Error after 500 iterations: 0.451013
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 10.582402
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.8537237, gradient norm = 0.0021299 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.6545423, gradient norm = 0.0033820 (50 iterations in 0.028s)
# [t-SNE] Iteration 150: error = 0.8786838, gradient norm = 0.0010972 (50 iterations in 0.028s)
# [t-SNE] Iteration 200: error = 0.7238256, gradient norm = 0.0007479 (50 iterations in 0.028s)
# [t-SNE] Iteration 250: error = 1.4859676, gradient norm = 0.0005758 (50 iterations in 0.024s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 1.485968
# [t-SNE] Iteration 300: error = 1.4223552, gradient norm = 0.0004572 (50 iterations in 0.032s)
# [t-SNE] Iteration 350: error = 1.3134736, gradient norm = 0.0003215 (50 iterations in 0.024s)
# [t-SNE] Iteration 400: error = 1.2169627, gradient norm = 0.0002414 (50 iterations in 0.024s)
# [t-SNE] Iteration 450: error = 1.1348388, gradient norm = 0.0001954 (50 iterations in 0.020s)
# [t-SNE] Iteration 500: error = 1.0612406, gradient norm = 0.0001677 (50 iterations in 0.028s)
# [t-SNE] Error after 500 iterations: 1.061241
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.036s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.036s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 21.082879
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.8332756, gradient norm = 0.0017371 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.9139241, gradient norm = 0.0027122 (50 iterations in 0.024s)
# [t-SNE] Iteration 150: error = 0.7782633, gradient norm = 0.0003071 (50 iterations in 0.032s)
# [t-SNE] Iteration 200: error = 0.7624305, gradient norm = 0.0002483 (50 iterations in 0.024s)
# [t-SNE] Iteration 250: error = 1.0194448, gradient norm = 0.0009206 (50 iterations in 0.028s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 1.019445
# [t-SNE] Iteration 300: error = 0.8724035, gradient norm = 0.0007216 (50 iterations in 0.024s)
# [t-SNE] Iteration 350: error = 0.7634497, gradient norm = 0.0001894 (50 iterations in 0.032s)
# [t-SNE] Iteration 400: error = 0.7292959, gradient norm = 0.0003908 (50 iterations in 0.024s)
# [t-SNE] Iteration 450: error = 1.5155834, gradient norm = 0.0010563 (50 iterations in 0.036s)
# [t-SNE] Iteration 500: error = 1.3314058, gradient norm = 0.0006150 (50 iterations in 0.032s)
# [t-SNE] Error after 500 iterations: 1.331406
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 10.568401
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.9285682, gradient norm = 0.0038726 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.7102067, gradient norm = 0.0031394 (50 iterations in 0.032s)
# [t-SNE] Iteration 150: error = 0.7920978, gradient norm = 0.0010949 (50 iterations in 0.032s)
# [t-SNE] Iteration 200: error = 0.4292735, gradient norm = 0.0001359 (50 iterations in 0.028s)
# [t-SNE] Iteration 250: error = 0.4276067, gradient norm = 0.0000572 (50 iterations in 0.028s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.427607
# [t-SNE] Iteration 300: error = 0.4274051, gradient norm = 0.0000342 (50 iterations in 0.032s)
# [t-SNE] Iteration 350: error = 0.4266875, gradient norm = 0.0000349 (50 iterations in 0.024s)
# [t-SNE] Iteration 400: error = 0.4264084, gradient norm = 0.0000312 (50 iterations in 0.024s)
# [t-SNE] Iteration 450: error = 0.4264023, gradient norm = 0.0000209 (50 iterations in 0.020s)
# [t-SNE] Iteration 500: error = 0.4272201, gradient norm = 0.0000286 (50 iterations in 0.020s)
# [t-SNE] Error after 500 iterations: 0.427220
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# ...
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.040s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.036s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.004s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.000s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.004s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.036s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.044s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.036s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.040s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.036s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.036s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 21.134792
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.4956627, gradient norm = 0.0008030 (50 iterations in 0.036s)
# [t-SNE] Iteration 100: error = 0.6416708, gradient norm = 0.0103902 (50 iterations in 0.028s)
# [t-SNE] Iteration 150: error = 0.9171628, gradient norm = 0.0012977 (50 iterations in 0.028s)
# [t-SNE] Iteration 200: error = 0.7530637, gradient norm = 0.0006147 (50 iterations in 0.032s)
# [t-SNE] Iteration 250: error = 0.8690550, gradient norm = 0.0009157 (50 iterations in 0.032s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.869055
# [t-SNE] Iteration 300: error = 0.7718002, gradient norm = 0.0004519 (50 iterations in 0.028s)
# [t-SNE] Iteration 350: error = 0.5828140, gradient norm = 0.0047979 (50 iterations in 0.024s)
# [t-SNE] Iteration 400: error = 1.1435883, gradient norm = 0.0004880 (50 iterations in 0.024s)
# [t-SNE] Iteration 450: error = 1.0462232, gradient norm = 0.0003583 (50 iterations in 0.028s)
# [t-SNE] Iteration 500: error = 0.9418967, gradient norm = 0.0002965 (50 iterations in 0.024s)
# [t-SNE] Error after 500 iterations: 0.941897
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.004s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 27 nearest neighbors...
# [t-SNE] Indexed 28 samples in 0.000s...
# [t-SNE] Computed neighbors for 28 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 28 / 28
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000

# %%
#X_train = np.array(x_train)
print(X_train.shape)
print(X_test.shape)
# Out:
# (472, 28, 2)
# (119, 28, 2)

# %% [markdown]
# # *********++++++*********++++++*********++++++*********++++++

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras import regularizers
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D
# Out:
# C:\Users\lenovo_pc\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
feature_dim_1 = 2
feature_dim_2 = 28

model = Sequential()
model.add(Conv1D(64, 3, activation='relu', input_shape=(feature_dim_2,feature_dim_1), padding='causal'))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Conv1D(128, 1, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Conv1D(256, 1, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.9))
model.add(Dense(2, activation='sigmoid'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 28, 64)            448
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 26, 64)            12352
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 26, 64)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 26, 128)           8320
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 26, 128)           0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 26, 256)           33024
# _________________________________________________________________
# global_average_pooling1d_3 ( (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 54,658
# Trainable params: 54,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
history = model.fit(X_train, y_
# 472/472 [==============================] - 11s 23ms/step - loss: 0.6936 - acc: 0.5318 - val_loss: 0.6962 - val_acc: 0.4874
# Epoch 48/50
# 472/472 [==============================] - 11s 24ms/step - loss: 0.6884 - acc: 0.5350 - val_loss: 0.6963 - val_acc: 0.4874
# Epoch 49/50
# 472/472 [==============================] - 10s 22ms/step - loss: 0.6910 - acc: 0.5307 - val_loss: 0.6965 - val_acc: 0.4874
# Epoch 50/50
# 472/472 [==============================] - 12s 24ms/step - loss: 0.6926 - acc: 0.5297 - val_loss: 0.6962 - val_acc: 0.4874

# %%
score = model.evaluate(X_train, y_train_hot, verbose=0) 
print ("model train data score: acc       : ",round(score[1]*100) , "%")
print ("model train data score: loss      : ",round(score[0]*100) , "%")

score = model.evaluate(X_test, y_test_hot, verbose=0) 
print ("model test data score: acc        : ",round(score[1]*100) , "%")
print ("model test data score: loss       : ",round(score[0]*100) , "%")
# Out:
# model train data score: acc       :  53.0 %
# model train data score: loss      :  69.0 %
# model test data score: acc        :  49.0 %
# model test data score: loss       :  70.0 %

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # *********++++++*********++++++*********++++++*********++++++

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras import regularizers
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D

# %%
model = Sequential()
model.add(Conv1D(32, 3, activation='relu', input_shape=(feature_dim_2,feature_dim_1), padding='causal'))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(3))
model.add(Conv1D(128, 3, activation='relu'))
#model.add(Conv1D(128, 3, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.9))
model.add(Dense(2, activation='sigmoid'))

# %%
from keras import optimizers

#sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
#model.fit(x_train, y_train, batch_size=7, epochs=10)

history = model.fit(X_train, y_train_hot, batch_size=10, epochs=50, verbose=verbose, validation_data=(X_test, y_test_hot))
# Out:
# Train on 472 samples, validate on 119 samples
# Epoch 1/50
# 472/472 [==============================] - 2s 4ms/step - loss: 0.7010 - acc: 0.5138 - val_loss: 0.6952 - val_acc: 0.4874
# Epoch 2/50
# 472/472 [==============================] - 0s 947us/step - loss: 0.7032 - acc: 0.5233 - val_loss: 0.6965 - val_acc: 0.4874
# Epoch 3/50
# 472/472 [==============================] - 0s 818us/step - loss: 0.6970 - acc: 0.5011 - val_loss: 0.6943 - val_acc: 0.4832
# Epoch 4/50
# 472/472 [==============================] - 0s 719us/step - loss: 0.6952 - acc: 0.4958 - val_loss: 0.6947 - val_acc: 0.4874
# Epoch 5/50
# 472/472 [==============================] - 0s 916us/step - loss: 0.6929 - acc: 0.5275 - val_loss: 0.6941 - val_acc: 0.4874
# Epoch 6/50
# 472/472 [==============================] - 0s 886us/step - loss: 0.6910 - acc: 0.5360 - val_loss: 0.6946 - val_acc: 0.4874
# Epoch 7/50
# 472/472 [==============================] - 0s 941us/step - loss: 0.6901 - acc: 0.5477 - val_loss: 0.6947 - val_acc: 0.4874
# Epoch 8/50
# 472/472 [==============================] - 0s 880us/step - loss: 0.6916 - acc: 0.5371 - val_loss: 0.6978 - val_acc: 0.4874
# Epoch 9/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6936 - acc: 0.5254 - val_loss: 0.6960 - val_acc: 0.4874
# Epoch 10/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6927 - acc: 0.5212 - val_loss: 0.6959 - val_acc: 0.4874
# Epoch 11/50
# 472/472 [==============================] - 0s 835us/step - loss: 0.6933 - acc: 0.5138 - val_loss: 0.6969 - val_acc: 0.4874
# Epoch 12/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0
# Epoch 34/50
# 472/472 [==============================] - 0s 884us/step - loss: 0.5582 - acc: 0.7203 - val_loss: 0.7948 - val_acc: 0.4412
# Epoch 35/50
# 472/472 [==============================] - 0s 888us/step - loss: 0.5262 - acc: 0.7500 - val_loss: 0.7973 - val_acc: 0.5000
# Epoch 36/50
# 472/472 [==============================] - 0s 984us/step - loss: 0.5125 - acc: 0.7701 - val_loss: 0.7853 - val_acc: 0.4832
# Epoch 37/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.4971 - acc: 0.7765 - val_loss: 0.8288 - val_acc: 0.5336
# Epoch 38/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.4981 - acc: 0.7553 - val_loss: 0.8467 - val_acc: 0.4412
# Epoch 39/50
# 472/472 [==============================] - 1s 2ms/step - loss: 0.5243 - acc: 0.7479 - val_loss: 0.8039 - val_acc: 0.4874
# Epoch 40/50
# 472/472 [==============================] - 1s 2ms/step - loss: 0.4805 - acc: 0.7754 - val_loss: 0.8242 - val_acc: 0.4916
# Epoch 41/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.4543 - acc: 0.7987 - val_loss: 0.8988 - val_acc: 0.5042
# Epoch 42/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.4430 - acc: 0.8008 - val_loss: 0.8766 - val_acc: 0.4916
# Epoch 43/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.4398 - acc: 0.8040 - val_loss: 0.9058 - val_acc: 0.5168
# Epoch 44/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.3691 - acc: 0.8538 - val_loss: 0.9268 - val_acc: 0.4958
# Epoch 45/50
# 472/472 [==============================] - 1s 2ms/step - loss: 0.3499 - acc: 0.8464 - val_loss: 0.9649 - val_acc: 0.5252
# Epoch 46/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.3921 - acc: 0.8263 - val_loss: 0.9508 - val_acc: 0.4790
# Epoch 47/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.3373 - acc: 0.8612 - val_loss: 0.9593 - val_acc: 0.5126
# Epoch 48/50
# 472/472 [==============================] - 1s 2ms/step - loss: 0.3177 - acc: 0.8708 - val_loss: 1.0176 - val_acc: 0.4958
# Epoch 49/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.3135 - acc: 0.8824 - val_loss: 1.0055 - val_acc: 0.4916
# Epoch 50/50
# 472/472 [==============================] - 1s 1ms/step - loss: 0.2830 - acc: 0.8994 - val_loss: 1.1108 - val_acc: 0.4958

# %%
score = model.evaluate(X_train, y_train_hot, verbose=0) 
print ("model train data score: acc       : ",round(score[1]*100) , "%")
print ("model train data score: loss      : ",round(score[0]*100) , "%")

score = model.evaluate(X_test, y_test_hot, verbose=0) 
print ("model test data score: acc        : ",round(score[1]*100) , "%")
print ("model test data score: loss       : ",round(score[0]*100) , "%")
# Out:
# model train data score: acc       :  100.0 %
# model train data score: loss      :  0.0 %
# model test data score: acc        :  47.0 %
# model test data score: loss       :  217.0 %

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # RNN+LSTM

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, LSTM
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint,TensorBoard,ProgbarLogger
from keras.utils import np_utils
from sklearn import metrics 
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import itertools

# %%
print('Build LSTM RNN model ...')
model = Sequential()
model.add(LSTM(units=64, dropout=0.05, recurrent_dropout=0.20, return_sequences=True))
model.add(LSTM(units=32, dropout=0.5, recurrent_dropout=0.5, return_sequences=False))
model.add(Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='Adamax', metrics=['acc','mse', 'mae', 'mape', 'cosine'])
# Out:
# Build LSTM RNN model ...

# %%
# %%time
# saved model checkpoint file
best_model_file="./best_model_trained.hdf5"
#train_model_file=file_path+"/checkpoints/weights.best_{epoch:02d}-{loss:.2f}.hdf5"
MAX_PATIENT=12
MAX_EPOCHS=150
MAX_BATCH=7

# callbacks
# removed EarlyStopping(patience=MAX_PATIENT)
callback=[ReduceLROnPlateau(patience=MAX_PATIENT, verbose=1),
          ModelCheckpoint(filepath=best_model_file, monitor='loss', verbose=1, save_best_only=True)]

print ("training started..... please wait.")
# training
history=model.fit(X_train, y_train_hot, 
                  batch_size=MAX_BATCH, 
                  epochs=MAX_EPOCHS,
                  verbose=0,
                  validation_data=(X_test, y_test_hot),
                  callbacks=callback) 

print ("training finised!")
# Out:
# training started..... please wait.
#
# Epoch 00001: loss improved from inf to 0.69530, saving model to ./best_model_trained.hdf5
#
# Epoch 00002: loss improved from 0.69530 to 0.68921, saving model to ./best_model_trained.hdf5
#
# Epoch 00003: loss did not improve from 0.68921
#
# Epoch 00004: loss improved from 0.68921 to 0.68730, saving model to ./best_model_trained.hdf5
#
# Epoch 00005: loss did not improve from 0.68730
#
# Epoch 00006: loss did not improve from 0.68730
#
# Epoch 00007: loss did not improve from 0.68730
#
# Epoch 00008: loss improved from 0.68730 to 0.68648, saving model to ./best_model_trained.hdf5
#
# Epoch 00009: loss did not improve from 0.68648
#
# Epoch 00010: loss improved from 0.68648 to 0.68471, saving model to ./best_model_trained.hdf5
#
# Epoch 00011: loss improved from 0.68471 to 0.68451, saving model to ./best_model_trained.hdf5
#
# Epoch 00012: loss improved from 0.68451 to 0.68238, saving model to ./best_model_trained.hdf5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00013: loss did not improve from 0.68238
#
# Epoch 00014: loss did not improve from 0.68238
#
# Epoch 00015: loss improved from 0.68238 to 0.67805, saving model to ./best_model_trained.hdf5
#
# Epoch 00016: loss did not improve from 0.67805
#
# Epoch 00017: loss did not improve from 0.67805
#
# Epoch 00018: loss improved from 0.67805 to 0.67777, saving model to ./best_model_trained.hdf5
#
# Epoch 00019: loss did not improve from 0.67777
#
# Epoch 00020: loss improved from 0.67777 to 0.67750, saving model to ./best_model_trained.hdf5
#
# Epoch 00021: loss improved from 0.67750 to 0.67650, saving model to ./best_model_trained.hdf5
#
# Epoch 00022: loss did not improve from 0.67650
#
# Epoch 00023: loss did not improve from 0.67650
#
# Epoch 00024: loss improved from 0.67650 to 0.67618, saving model to ./best_model_trained.hdf5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
#
# Epoch 00025: loss did not improve from 0.67618
#
# Epoch 00026: loss did not improve from 0.67618
#
# Epoch 00027: loss did not improve from 0.67618
#
# Epoch 00028: loss did not improve from 0.67618
#
# Epoch 00029: loss did not improve from 0.67618
#
# Epoch 00030: loss improved from 0.67618 to 0.67596, saving model to ./best_model_trained.hdf5
#
# Epoch 00031: loss did not improve from 0.67596
#
# Epoch 00032: loss did not improve from 0.67596
#
# Epoch 00033: loss improved from 0.67596 to 0.66797, saving model to ./best_model_trained.hdf5
#
# Epoch 00034: loss did not improve from 0.66797
#
# Epoch 00035: loss did not improve from 0.66797
#
# Epoch 00036: loss did not improve from 0.66797
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 2.0000001313746906e-06.
#
# Epoch 00037: loss did not improve from 0.66797
#
# Epoch 00038: loss did not improve from 0.66797
#
# Epoch 00039: loss did not improve from 0.66797
#
# Epoch 00040: loss did not improve from 0.66797
#
# Epoch 00041: loss did not improve from 0.66797
#
# Epoch 00042: loss did not improve from 0.66797
#
# Epoch 00043: loss did not improve from 0.66797
#
# Epoch 00044: loss did not improve from 0.66797
#
# Epoch 00045: loss did not improve from 0.66797
#
# Epoch 00046: loss did not improve from 0.66797
#
# Epoch 00047: loss did not improve from 0.66797
#
# Epoch 00048: loss did not improve from 0.66797
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 2.000000222324161e-07.
#
# Epoch 00049: loss did not improve from 0.66797
#
# Epoch 00050: loss did not improve from 0.66797
#
# Epoch 00051: loss did not improve from 0.66797
#
# Epoch 00052: loss did not improve from 0.66797
#
# Epoch 00053: loss did not improve from 0.66797
#
# Epoch 00054: loss did not improve from 0.66797
#
# Epoch 00055: loss did not improve from 0.66797
#
# Epoch 00056: loss did not improve from 0.66797
#
# Epoch 00057: loss did not improve from 0.66797
#
# Epoch 00058: loss did not improve from 0.66797
#
# Epoch 00059: loss did not improve from 0.66797
#
# Epoch 00060: loss did not improve from 0.66797
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 2.000000165480742e-08.
#
# Epoch 00061: loss did not improve from 0.66797
#
# Epoch 00062: loss did not improve from 0.66797
#
# Epoch 00063: loss did not improve from 0.66797
#
# Epoch 00064: loss did not improve from 0.66797
#
# Epoch 00065: loss did not improve from 0.66797
#
# Epoch 00066: loss did not improve from 0.66797
#
# Epoch 00067: loss did not improve from 0.66797
#
# Epoch 00068: loss did not improve from 0.66797
#
# Epoch 00069: loss did not improve from 0.66797
#
# Epoch 00070: loss improved from 0.66797 to 0.66521, saving model to ./best_model_trained.hdf5
#
# Epoch 00071: loss did not improve from 0.66521
#
# Epoch 00072: loss did not improve from 0.66521
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 2.000000165480742e-09.
#
# Epoch 00073: loss did not improve from 0.66521
#
# Epoch 00074: loss did not improve from 0.66521
#
# Epoch 00075: loss did not improve from 0.66521
#
# Epoch 00076: loss did not improve from 0.66521
#
# Epoch 00077: loss did not improve from 0.66521
#
# Epoch 00078: loss did not improve from 0.66521
#
# Epoch 00079: loss did not improve from 0.66521
#
# Epoch 00080: loss did not improve from 0.66521
#
# Epoch 00081: loss did not improve from 0.66521
#
# Epoch 00082: loss did not improve from 0.66521
#
# Epoch 00083: loss did not improve from 0.66521
#
# Epoch 00084: loss did not improve from 0.66521
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 2.000000165480742e-10.
#
# Epoch 00085: loss did not improve from 0.66521
#
# Epoch 00086: loss did not improve from 0.66521
#
# Epoch 00087: loss did not improve from 0.66521
#
# Epoch 00088: loss did not improve from 0.66521
#
# Epoch 00089: loss did not improve from 0.66521
#
# Epoch 00090: loss did not improve from 0.66521
#
# Epoch 00091: loss did not improve from 0.66521
#
# Epoch 00092: loss did not improve from 0.66521
#
# Epoch 00093: loss did not improve from 0.66521
#
# Epoch 00094: loss did not improve from 0.66521
#
# Epoch 00095: loss did not improve from 0.66521
#
# Epoch 00096: loss did not improve from 0.66521
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 2.000000165480742e-11.
#
# Epoch 00097: loss did not improve from 0.66521
#
# Epoch 00098: loss did not improve from 0.66521
#
# Epoch 00099: loss did not improve from 0.66521
#
# Epoch 00100: loss did not improve from 0.66521
#
# Epoch 00101: loss did not improve from 0.66521
#
# Epoch 00102: loss did not improve from 0.66521
#
# Epoch 00103: loss did not improve from 0.66521
#
# Epoch 00104: loss did not improve from 0.66521
#
# Epoch 00105: loss did not improve from 0.66521
#
# Epoch 00106: loss did not improve from 0.66521
#
# Epoch 00107: loss did not improve from 0.66521
#
# Epoch 00108: loss did not improve from 0.66521
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 2.000000165480742e-12.
#
# Epoch 00109: loss did not improve from 0.66521
#
# Epoch 00110: loss did not improve from 0.66521
#
# Epoch 00111: loss did not improve from 0.66521
#
# Epoch 00112: loss did not improve from 0.66521
#
# Epoch 00113: loss did not improve from 0.66521
#
# Epoch 00114: loss did not improve from 0.66521
#
# Epoch 00115: loss did not improve from 0.66521
#
# Epoch 00116: loss did not improve from 0.66521
#
# Epoch 00117: loss did not improve from 0.66521
#
# Epoch 00118: loss did not improve from 0.66521
#
# Epoch 00119: loss did not improve from 0.66521
#
# Epoch 00120: loss did not improve from 0.66521
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 2.000000208848829e-13.
#
# Epoch 00121: loss did not improve from 0.66521
#
# Epoch 00122: loss did not improve from 0.66521
#
# Epoch 00123: loss did not improve from 0.66521
#
# Epoch 00124: loss did not improve from 0.66521
#
# Epoch 00125: loss did not improve from 0.66521
#
# Epoch 00126: loss did not improve from 0.66521
#
# Epoch 00127: loss did not improve from 0.66521
#
# Epoch 00128: loss did not improve from 0.66521
#
# Epoch 00129: loss did not improve from 0.66521
#
# Epoch 00130: loss did not improve from 0.66521
#
# Epoch 00131: loss did not improve from 0.66521
#
# Epoch 00132: loss did not improve from 0.66521
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 2.0000002359538835e-14.
#
# Epoch 00133: loss did not improve from 0.66521
#
# Epoch 00134: loss did not improve from 0.66521
#
# Epoch 00135: loss did not improve from 0.66521
#
# Epoch 00136: loss did not improve from 0.66521
#
# Epoch 00137: loss did not improve from 0.66521
# Epoch 00138: loss did not improve from 0.66521
#
# Epoch 00139: loss did not improve from 0.66521
#
# Epoch 00140: loss did not improve from 0.66521
#
# Epoch 00141: loss did not improve from 0.66521
#
# Epoch 00142: loss did not improve from 0.66521
#
# Epoch 00143: loss did not improve from 0.66521
#
# Epoch 00144: loss did not improve from 0.66521
#
# Epoch 00145: ReduceLROnPlateau reducing learning rate to 2.000000303716519e-15.
#
# Epoch 00145: loss did not improve from 0.66521
#
# Epoch 00146: loss did not improve from 0.66521
#
# Epoch 00147: loss did not improve from 0.66521
#
# Epoch 00148: loss did not improve from 0.66521
#
# Epoch 00149: loss did not improve from 0.66521
#
# Epoch 00150: loss did not improve from 0.66521
# training finised!
# Wall time: 8min 33s

# %%
score = model.evaluate(X_train, y_train_hot, verbose=0) 
print ("model train data score       : ",round(score[1]*100,2) , "%")
print ("model train data loss        : ",round(score[0],2))

score = model.evaluate(X_test, y_test_hot, verbose=0) 
print ("model test data score        : ",round(score[1]*100,2) , "%")
print ("model train data loss        : ",round(score[0],2))
# Out:
# model train data score       :  56.57 %
# model train data loss        :  0.68
# model test data score        :  45.38 %
# model train data loss        :  0.72

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
